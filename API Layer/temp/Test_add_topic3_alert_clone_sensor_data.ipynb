# %% [markdown]
# # Test notebook

# %%
import requests
import os

# load the correct host name from the environment if defined
HOSTNAME = os.getenv('API_HOSTNAME', 'localhost')
PORT = 443
BASE_URL = f'https://{HOSTNAME}:{PORT}'

YOUR_USERNAME = 'mario.rossi'# change this, until topic 7 gives you real credentials anything will work
YOUR_PASSWORD = 'password1'# change this, until topic 7 gives you real credentials anything will work

# %%
AUTH_URL = f'{BASE_URL}/user/login'

auth_token = None

def get_token(url, username, password):
    headers = {
        'username': username,
        'password': password
    }  
    response = requests.post(url, headers=headers, verify=False)
    if response.status_code == 200:
        print('You are authenticated!')
        return response.json()
    elif response.status_code == 400:
        print('Wrong credentials')
    elif response.status_code == 500:
        print('Connection error')
    else:
        print('Unknown error')
    return None

def call_with_token(url, token, call_type='GET', header_params=None):
    headers = {} if header_params is None else header_params
    headers['Authorization'] = token
    if call_type == 'GET':
        response = requests.get(url, headers=headers, verify=False)
    elif call_type == 'POST':
        response = requests.post(url, headers=headers, verify=False)
    elif call_type == 'PUT':
        response = requests.put(url, headers=headers, verify=False)
    elif call_type == 'DELETE':
        response = requests.delete(url, headers=headers, verify=False)
    else:
        print('Unknown call type')
        return None, None
    if response.status_code == 500:
        print('Server error: ', response.reason)
        return None, response.status_code
    elif response.status_code == 400:
        print('Bad request: ', response.reason)
        return None, response.status_code
    elif response.status_code == 401:
        print('Unauthorized')
        return None, response.status_code
    elif response.status_code == 200 or response.status_code == 201:
        return response.json(), response.status_code
    else:
        print('Unknown error: ', response.reason)
        return None, response.status_code
    
def call_and_retry(url, token, call_type='GET', header_params=None):
    response, status = call_with_token(url, token, call_type, header_params)
    if status == 401:
        print('Token expired, getting new token')
        token = get_token(AUTH_URL, YOUR_USERNAME, YOUR_PASSWORD)
        global auth_token
        auth_token = token
        if token is None:
            print('Failed to get new token')
            return None, 401
        return call_and_retry(url, token, call_type, header_params)
    return response, status

# %% [markdown]
# ## Get an authentication token

# %%
auth_token = get_token(AUTH_URL, YOUR_USERNAME, YOUR_PASSWORD)
print('Token: ', auth_token)
# Out:
# You are authenticated!
# Token:  Bearer token6493
# c:\Users\andre\anaconda3\envs\HLT\lib\site-packages\urllib3\connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %% [markdown]
# ## Get machine list

# %% [markdown]
# When you call an API method, you need the authentication token.
# The token may be expired if some time has passed since you got it, so you should get a new one before calling the API if you get an authentication error.

# %%
#get machine list
MACHINE_URL = f'{BASE_URL}/machine'
machines, status = call_and_retry(MACHINE_URL, auth_token)
if status == 200:
    print('Machines: ', machines)
else:
    print('Failed to get machines')
# Out:
# Machines:  [{'factory': 'Unknown', 'id': 1, 'machineType': 'Large Capacity Cutting Machine', 'name': 'Large Capacity Cutting Machine 1', 'productionLine': 1, 'status': 'Down'}, {'factory': 'Unknown', 'id': 2, 'machineType': 'Riveting Machine', 'name': 'Riveting Machine', 'productionLine': 0, 'status': 'Down'}, {'factory': 'Unknown', 'id': 3, 'machineType': 'Medium Capacity Cutting Machine', 'name': 'Medium Capacity Cutting Machine 1', 'productionLine': 1, 'status': 'Down'}, {'factory': 'Unknown', 'id': 4, 'machineType': 'Laser Cutter', 'name': 'Laser Cutter', 'productionLine': 0, 'status': 'Down'}, {'factory': 'Unknown', 'id': 5, 'machineType': 'Large Capacity Cutting Machine', 'name': 'Large Capacity Cutting Machine 2', 'productionLine': 2, 'status': 'Down'}, {'factory': 'Unknown', 'id': 6, 'machineType': 'Medium Capacity Cutting Machine', 'name': 'Medium Capacity Cutting Machine 2', 'productionLine': 2, 'status': 'Down'}, {'factory': 'Unknown', 'id': 7, 'machineType': 'Testing Machine', 'name': 'Testing Machine 1', 'productionLine': 1, 'status': 'Down'}, {'factory': 'Unknown', 'id': 8, 'machineType': 'Testing Machine', 'name': 'Testing Machine 2', 'productionLine': 2, 'status': 'Down'}, {'factory': 'Unknown', 'id': 9, 'machineType': 'Low Capacity Cutting Machine', 'name': 'Low Capacity Cutting Machine 1', 'productionLine': 1, 'status': 'Down'}, {'factory': 'Unknown', 'id': 10, 'machineType': 'Medium Capacity Cutting Machine', 'name': 'Medium Capacity Cutting Machine 3', 'productionLine': 3, 'status': 'Down'}, {'factory': 'Unknown', 'id': 11, 'machineType': 'Assembly Machine', 'name': 'Assembly Machine 1', 'productionLine': 1, 'status': 'Down'}, {'factory': 'Unknown', 'id': 12, 'machineType': 'Laser Welding Machine', 'name': 'Laser Welding Machine 1', 'productionLine': 1, 'status': 'Down'}, {'factory': 'Unknown', 'id': 13, 'machineType': 'Assembly Machine', 'name': 'Assembly Machine 2', 'productionLine': 2, 'status': 'Down'}, {'factory': 'Unknown', 'id': 14, 'machineType': 'Assembly Machine', 'name': 'Assembly Machine 3', 'productionLine': 3, 'status': 'Down'}, {'factory': 'Unknown', 'id': 15, 'machineType': 'Laser Welding Machine', 'name': 'Laser Welding Machine 2', 'productionLine': 2, 'status': 'Down'}, {'factory': 'Unknown', 'id': 16, 'machineType': 'Testing Machine', 'name': 'Testing Machine 3', 'productionLine': 3, 'status': 'Down'}]
# c:\Users\andre\anaconda3\envs\HLT\lib\site-packages\urllib3\connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %% [markdown]
# ## Add an alert

# %%
ENDPOINT_URL = f'{BASE_URL}/alert'
HEADERS = {
    "timestamp": "2023-10-01 08:00:00",
    "machineID": "1",
    "severity": "low",
    "description": "This is a test alert",
    "KPI": "sum(Temperature) > 300"
}
new_id, status = call_and_retry(ENDPOINT_URL, auth_token, call_type='POST', header_params=HEADERS)
if status == 201:
    print('Alert added: ', new_id)
else:
    print('Failed to add alerts')
# Out:
# c:\Users\andre\anaconda3\envs\HLT\lib\site-packages\urllib3\connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Unknown error:  CREATED
# Alert added:  None

# %%
#get the new alert
ALERT_URL = f'{BASE_URL}/alert/id/{new_id}'
alert, status = call_and_retry(ALERT_URL, auth_token)
if status == 200:
    print('Alert: ', alert)
else:
    print('Failed to get alert')
# Out:
# Unknown error:  NOT FOUND
# Failed to get alert
# c:\Users\andre\anaconda3\envs\HLT\lib\site-packages\urllib3\connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'localhost'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
import pickle

# %%
alert_file = 'saved_alerts.pkl'
# read
if os.path.exists(alert_file):
    with open(alert_file, 'rb') as f:
        alerts = pickle.load(f)

# %%
ENDPOINT_URL = f'{BASE_URL}/alert'

for alert in alerts:
    new_id, status = call_and_retry(ENDPOINT_URL, auth_token, call_type='POST', header_params=alert)
    if status == 201:
        print('Alert added: ', new_id)
    else:
        print('Failed to add alerts')

# %%
import pandas as pd

# %%
alerts
# Out:
# [{'timestamp': '2024-09-19 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 7 samples, with respect to the previous 28 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-20 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 7 samples, with respect to the previous 28 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-21 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 7 samples, with respect to the previous 28 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-22 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 7 samples, with respect to the previous 28 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-23 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 7 samples, with respect to the previous 28 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-05-06 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A negative trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-05-10 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A negative trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-08-01 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A negative trend drift was detected during the last 30 samples, with respect to the previous 120 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-08-02 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A negative trend drift was detected during the last 30 samples, with respect to the previous 120 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-08-03 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A negative trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-08-04 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A negative trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-08-05 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A negative trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-08-06 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A negative trend drift was detected during the last 30 samples, with respect to the previous 120 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-08-07 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 120 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-08-08 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 120 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-08-09 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 120 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-08-18 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 120 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-08-19 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-08-20 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-08-21 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-08-22 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-08-23 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-08-24 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-08-25 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-08-26 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-08-27 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-08-28 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-08-29 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-08-30 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-08-31 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-01 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-02 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-03 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-16 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-17 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-18 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-19 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-20 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-21 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-22 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-23 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-24 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-25 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-26 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-27 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-28 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-29 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-30 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-01 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-02 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-03 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-04 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-05 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-06 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-07 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-08 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-09 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A negative trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-10 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A negative trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-11 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A negative trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-12 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A negative trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-13 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A negative trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-14 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A negative trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-15 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A negative trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-16 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A negative trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-17 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-18 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-08-21 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 120 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-08-22 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A negative trend drift was detected during the last 30 samples, with respect to the previous 120 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-08-23 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 120 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-08-24 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-08-25 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-08-26 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-08-27 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-08-28 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-08-29 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-08-30 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-08-31 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-01 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-02 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-03 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-16 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-17 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-18 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-19 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-20 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-21 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-22 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-23 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-24 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-25 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-26 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-27 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-28 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-29 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-30 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-01 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-02 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-03 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-04 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-05 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-06 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-07 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-08 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-09 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-10 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-11 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-12 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-13 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-14 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-15 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-16 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-17 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-18 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-08-22 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 120 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-08-23 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 120 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-08-24 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-08-25 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-08-26 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-08-27 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-08-28 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-08-29 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-08-30 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-08-31 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-01 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-02 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-03 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-04 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-05 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-16 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-17 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-18 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-19 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A negative trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-20 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A negative trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-21 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A negative trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-22 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A negative trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-23 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A negative trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-24 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A negative trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-25 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A negative trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-26 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A negative trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-27 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A negative trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-28 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A negative trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-29 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A negative trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-30 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-01 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-02 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-03 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-04 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-05 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-06 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-07 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-08 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-09 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-10 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-11 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-12 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-13 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-14 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-15 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-16 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-17 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-10-18 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'consumption_working'},
#  {'timestamp': '2024-09-14 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 7 samples, with respect to the previous 21 samples',
#   'KPI': 'average_cycle_time'},
#  {'timestamp': '2024-09-15 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 7 samples, with respect to the previous 21 samples',
#   'KPI': 'average_cycle_time'},
#  {'timestamp': '2024-09-16 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 7 samples, with respect to the previous 21 samples',
#   'KPI': 'average_cycle_time'},
#  {'timestamp': '2024-09-17 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 7 samples, with respect to the previous 28 samples',
#   'KPI': 'average_cycle_time'},
#  {'timestamp': '2024-09-18 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 7 samples, with respect to the previous 28 samples',
#   'KPI': 'average_cycle_time'},
#  {'timestamp': '2024-09-19 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 7 samples, with respect to the previous 28 samples',
#   'KPI': 'average_cycle_time'},
#  {'timestamp': '2024-09-20 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 7 samples, with respect to the previous 28 samples',
#   'KPI': 'average_cycle_time'},
#  {'timestamp': '2024-09-21 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 7 samples, with respect to the previous 28 samples',
#   'KPI': 'average_cycle_time'},
#  {'timestamp': '2024-09-22 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 7 samples, with respect to the previous 28 samples',
#   'KPI': 'average_cycle_time'},
#  {'timestamp': '2024-09-23 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 7 samples, with respect to the previous 28 samples',
#   'KPI': 'average_cycle_time'},
#  {'timestamp': '2024-10-14 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 7 samples, with respect to the previous 21 samples',
#   'KPI': 'average_cycle_time'},
#  {'timestamp': '2024-10-15 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 7 samples, with respect to the previous 28 samples',
#   'KPI': 'average_cycle_time'},
#  {'timestamp': '2024-10-16 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 7 samples, with respect to the previous 28 samples',
#   'KPI': 'average_cycle_time'},
#  {'timestamp': '2024-09-12 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'average_cycle_time'},
#  {'timestamp': '2024-09-13 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'average_cycle_time'},
#  {'timestamp': '2024-09-14 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'average_cycle_time'},
#  {'timestamp': '2024-09-15 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'average_cycle_time'},
#  {'timestamp': '2024-09-16 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'average_cycle_time'},
#  {'timestamp': '2024-09-17 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'average_cycle_time'},
#  {'timestamp': '2024-09-18 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'average_cycle_time'},
#  {'timestamp': '2024-09-19 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'average_cycle_time'},
#  {'timestamp': '2024-09-20 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'average_cycle_time'},
#  {'timestamp': '2024-09-21 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'average_cycle_time'},
#  {'timestamp': '2024-09-22 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'average_cycle_time'},
#  {'timestamp': '2024-09-23 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'average_cycle_time'},
#  {'timestamp': '2024-09-24 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'average_cycle_time'},
#  {'timestamp': '2024-09-25 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'average_cycle_time'},
#  {'timestamp': '2024-09-26 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'average_cycle_time'},
#  {'timestamp': '2024-09-27 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'average_cycle_time'},
#  {'timestamp': '2024-09-28 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'average_cycle_time'},
#  {'timestamp': '2024-09-29 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'average_cycle_time'},
#  {'timestamp': '2024-09-30 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'average_cycle_time'},
#  {'timestamp': '2024-10-01 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'average_cycle_time'},
#  {'timestamp': '2024-10-02 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'average_cycle_time'},
#  {'timestamp': '2024-10-03 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'average_cycle_time'},
#  {'timestamp': '2024-10-04 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'average_cycle_time'},
#  {'timestamp': '2024-10-05 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'average_cycle_time'},
#  {'timestamp': '2024-10-06 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'average_cycle_time'},
#  {'timestamp': '2024-10-07 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'average_cycle_time'},
#  {'timestamp': '2024-10-08 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'average_cycle_time'},
#  {'timestamp': '2024-10-09 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'average_cycle_time'},
#  {'timestamp': '2024-10-10 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
# ...
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-06-11 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-06-12 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-06-13 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-06-14 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-06-15 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-06-16 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-06-17 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-06-18 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-06-19 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-06-20 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 30 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-06-21 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-06-22 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-06-23 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-06-24 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-06-25 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-06-26 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-06-27 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-06-28 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-06-29 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-06-30 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-07-01 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-07-02 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-07-03 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-07-04 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-07-05 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-07-06 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-07-07 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-07-08 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-07-09 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-07-10 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-07-11 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-07-12 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-07-13 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-07-14 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-07-15 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-07-16 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 60 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-07-17 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-07-18 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-07-19 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-07-20 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-07-21 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-07-22 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-07-23 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-07-24 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-07-25 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-07-26 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-07-27 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-07-28 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-07-29 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-07-30 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-07-31 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-08-01 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-08-02 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-08-03 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-08-04 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-08-05 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-08-06 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-08-07 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-08-08 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-08-09 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-08-10 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-08-11 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-08-12 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-08-13 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-08-14 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 90 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-08-15 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 120 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-08-16 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 120 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-08-17 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 120 samples',
#   'KPI': 'cost_working'},
#  {'timestamp': '2024-08-18 00:00:00',
#   'machineID': '2',
#   'severity': 'high',
#   'description': 'A positive trend drift was detected during the last 30 samples, with respect to the previous 120 samples',
#   'KPI': 'cost_working'},
#  ...]

# %%
# load alerts into a pandas dataframe
df = pd.DataFrame(alerts)
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#                  timestamp machineID severity  \
# 0      2024-09-19 00:00:00         2     high
# 1      2024-09-20 00:00:00         2     high
# 2      2024-09-21 00:00:00         2     high
# 3      2024-09-22 00:00:00         2     high
# 4      2024-09-23 00:00:00         2     high
# ...                    ...       ...      ...
# 11954  2024-09-22 00:00:00         4   medium
# 11955  2024-09-29 00:00:00         4   medium
# 11956  2024-10-03 00:00:00         4   medium
# 11957  2024-10-04 00:00:00         4   medium
# 11985  2024-12-17 22:29:40         4   medium
#
#                                              description                  KPI
# 0      A positive trend drift was detected during the...  consumption_working
# 1      A positive trend drift was detected during the...  consumption_working
# 2      A positive trend drift was detected during the...  consumption_working
# 3      A positive trend drift was detected during the...  consumption_working
# 4      A positive trend drift was detected during the...  consumption_working
# ...                                                  ...                  ...
# 11954                anomaly detected in historical data         working_time
# 11955                anomaly detected in historical data         working_time
# 11956                anomaly detected in historical data         working_time
# 11957                anomaly detected in historical data         working_time
# 11985  A minor anomaly has been detected in the strea...   average_cycle_time
#
# [4742 rows x 5 columns]

# %%
ENDPOINT_URL = f'{BASE_URL}/alert'

# %%
# insert all alerts into the database
for index, row in df.iterrows():
    HEADERS = {
        "timestamp": row['timestamp'],
        "machineID": row['machineID'],
        "severity": row['severity'],
        "description": row['description'],
        "KPI": row['KPI']
    }
    new_id, status = call_and_retry(ENDPOINT_URL, auth_token, call_type='POST', header_params=HEADERS)
    if status == 201:
        print('Alert added: ', new_id)
    else:
        print('Failed to add alerts')

# %%
preprocessed_data_file = 'data_features.pkl'
# read
if os.path.exists(preprocessed_data_file):
    with open(preprocessed_data_file, 'rb') as f:
        data = pickle.load(f)
data
# Out:
#        machineid               kpi aggregation_type            timestamp  \
# 0              3            cycles              sum  2024-03-01 00:00:00
# 1              3            cycles              sum  2024-03-02 00:00:00
# 2              3            cycles              sum  2024-03-03 00:00:00
# 3              3            cycles              sum  2024-03-04 00:00:00
# 4              3            cycles              sum  2024-03-05 00:00:00
# ...          ...               ...              ...                  ...
# 52653          4  consumption_idle              max  2024-10-15 00:00:00
# 52654          4  consumption_idle              max  2024-10-16 00:00:00
# 52655          4  consumption_idle              max  2024-10-17 00:00:00
# 52656          4  consumption_idle              max  2024-10-18 00:00:00
# 52657          4  consumption_idle              max  2024-10-19 00:00:00
#
#       trend_drift    value  imputation  anomaly  \
# 0             0.0   9126.0       False    False
# 1             0.0      2.0       False    False
# 2             0.0      0.0       False    False
# 3             0.0  61182.0       False    False
# 4             0.0    894.0       False    False
# ...           ...      ...         ...      ...
# 52653         0.0      0.0       False    False
# 52654         0.0      0.0       False    False
# 52655         0.0      0.0       False    False
# 52656         0.0      0.0       False    False
# 52657         0.0      0.0       False    False
#
#                                    next_days_predictions  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 52653                                               None
# 52654                                               None
# 52655                                               None
# 52656                                               None
# 52657  [3.4847078040911583e-06, 2.816192363752634e-07...
#
#                                confidence_interval_lower  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 52653                                               None
# 52654                                               None
# 52655                                               None
# 52656                                               None
# 52657  [3.4847077610118665e-06, 2.8161923237395835e-0...
#
#                                confidence_interval_upper
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 52653                                               None
# 52654                                               None
# 52655                                               None
# 52656                                               None
# 52657  [3.4847077610118665e-06, 2.8161923237395835e-0...
#
# [52425 rows x 11 columns]

# %%
data[data['machineid'] == 2]['kpi'].unique()
# Out:
# array(['consumption_working', 'average_cycle_time', 'consumption_idle',
#        'working_time', 'offline_time', 'cost_working', 'good_cycles',
#        'consumption', 'bad_cycles', 'idle_time', 'cost_idle', 'cycles',
#        'power', 'cost'], dtype=object)

# %%
with open('../../Storage/smart_app_data.pkl', 'rb') as f:
    sensor_data = pd.read_pickle(f)

# %%
MACHINE_NAME_TO_ID = {
    "Large Capacity Cutting Machine 1": 1,
    "Riveting Machine" : 2,
    "Medium Capacity Cutting Machine 1": 3,
    "Laser Cutter": 4,
    "Large Capacity Cutting Machine 2": 5,
    "Medium Capacity Cutting Machine 2": 6,
    "Testing Machine 1": 7,
    "Testing Machine 2": 8,
    "Low Capacity Cutting Machine 1": 9,
    "Medium Capacity Cutting Machine 3": 10,
    "Assembly Machine 1": 11,
    "Laser Welding Machine 1": 12,
    "Assembly Machine 2": 13,
    "Assembly Machine 3": 14,
    "Laser Welding Machine 2": 15,
    "Testing Machine 3": 16
}

# %%
sensor_data['machineid'] = sensor_data['name'].apply(lambda x: MACHINE_NAME_TO_ID[x])
sensor_data.drop(columns=['asset_id'], inplace=True)

# %%
sensor_data.drop(columns=['name'], inplace=True)

# %%
# rename columns
sensor_data.rename(columns={'time': 'timestamp'}, inplace=True)

# %%
# change timestamp to datetime from yyyy-mm-ddThh:mm:ssZ to yyyy-mm-dd hh:mm:ss
sensor_data['timestamp'] = sensor_data['timestamp'].apply(lambda x: x.replace('T', ' ').replace('Z', ''))

# %%
sensor_data['imputation'] = False
sensor_data['anomaly'] = False
sensor_data['next_days_predictions'] = None
sensor_data['confidence_interval_lower'] = None
sensor_data['confidence_interval_upper'] = None
sensor_data['trend drift'] = 0.0

# %%
sensor_data
# Out:
#                  timestamp                 kpi       sum       avg  min  \
# 0      2024-03-01 00:00:00        working_time  0.000000  0.000000  0.0
# 1      2024-03-01 00:00:00           idle_time  0.000000  0.000000  0.0
# 2      2024-03-01 00:00:00        offline_time  0.000000  0.000000  0.0
# 3      2024-03-01 00:00:00         consumption  0.066106  0.002321  0.0
# 4      2024-03-01 00:00:00               power       NaN  0.003673  0.0
# ...                    ...                 ...       ...       ...  ...
# 96915  2024-10-19 00:00:00           cost_idle  0.000000  0.000000  0.0
# 96924  2024-10-19 00:00:00              cycles  0.000000  0.000000  0.0
# 96925  2024-10-19 00:00:00         good_cycles  0.000000  0.000000  0.0
# 96926  2024-10-19 00:00:00          bad_cycles  0.000000  0.000000  0.0
# 96927  2024-10-19 00:00:00  average_cycle_time       NaN  0.000000  0.0
#
#             max  machineid  imputation  anomaly next_days_predictions  \
# 0      0.000000          1       False    False                  None
# 1      0.000000          1       False    False                  None
# 2      0.000000          1       False    False                  None
# 3      0.066106          1       False    False                  None
# 4      0.012801          1       False    False                  None
# ...         ...        ...         ...      ...                   ...
# 96915  0.000000         16       False    False                  None
# 96924  0.000000         16       False    False                  None
# 96925  0.000000         16       False    False                  None
# 96926  0.000000         16       False    False                  None
# 96927  0.000000         16       False    False                  None
#
#       confidence_interval_lower confidence_interval_upper  trend drift
# 0                          None                      None          0.0
# 1                          None                      None          0.0
# 2                          None                      None          0.0
# 3                          None                      None          0.0
# 4                          None                      None          0.0
# ...                         ...                       ...          ...
# 96915                      None                      None          0.0
# 96924                      None                      None          0.0
# 96925                      None                      None          0.0
# 96926                      None                      None          0.0
# 96927                      None                      None          0.0
#
# [52192 rows x 13 columns]

# %%
sensor_data_sum = sensor_data.drop(columns=['avg', 'min', 'max'])
sensor_data_sum.rename(columns={'sum': 'value'}, inplace=True)
sensor_data_sum['aggregation_type'] = 'sum'
sensor_data_max = sensor_data.drop(columns=['avg', 'min', 'sum'])
sensor_data_max.rename(columns={'max': 'value'}, inplace=True)
sensor_data_max['aggregation_type'] = 'max'
sensor_data_min = sensor_data.drop(columns=['avg', 'max', 'sum'])
sensor_data_min.rename(columns={'min': 'value'}, inplace=True)
sensor_data_min['aggregation_type'] = 'min'
sensor_data_avg = sensor_data.drop(columns=['min', 'max', 'sum'])
sensor_data_avg.rename(columns={'avg': 'value'}, inplace=True)
sensor_data_avg['aggregation_type'] = 'avg'
# merge all dataframes
sensor_data = pd.concat([sensor_data_sum, sensor_data_max, sensor_data_min, sensor_data_avg])
sensor_data
# Out:
#                  timestamp                 kpi     value  machineid  \
# 0      2024-03-01 00:00:00        working_time  0.000000          1
# 1      2024-03-01 00:00:00           idle_time  0.000000          1
# 2      2024-03-01 00:00:00        offline_time  0.000000          1
# 3      2024-03-01 00:00:00         consumption  0.066106          1
# 4      2024-03-01 00:00:00               power       NaN          1
# ...                    ...                 ...       ...        ...
# 96915  2024-10-19 00:00:00           cost_idle  0.000000         16
# 96924  2024-10-19 00:00:00              cycles  0.000000         16
# 96925  2024-10-19 00:00:00         good_cycles  0.000000         16
# 96926  2024-10-19 00:00:00          bad_cycles  0.000000         16
# 96927  2024-10-19 00:00:00  average_cycle_time  0.000000         16
#
#        imputation  anomaly next_days_predictions confidence_interval_lower  \
# 0           False    False                  None                      None
# 1           False    False                  None                      None
# 2           False    False                  None                      None
# 3           False    False                  None                      None
# 4           False    False                  None                      None
# ...           ...      ...                   ...                       ...
# 96915       False    False                  None                      None
# 96924       False    False                  None                      None
# 96925       False    False                  None                      None
# 96926       False    False                  None                      None
# 96927       False    False                  None                      None
#
#       confidence_interval_upper  trend drift aggregation_type
# 0                          None          0.0              sum
# 1                          None          0.0              sum
# 2                          None          0.0              sum
# 3                          None          0.0              sum
# 4                          None          0.0              sum
# ...                         ...          ...              ...
# 96915                      None          0.0              avg
# 96924                      None          0.0              avg
# 96925                      None          0.0              avg
# 96926                      None          0.0              avg
# 96927                      None          0.0              avg
#
# [208768 rows x 11 columns]
